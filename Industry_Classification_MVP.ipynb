# %% [markdown]
# # Classification MVP

# %% [markdown]
# The goal of my project is to build a classification model that has predictive power for companies in the Russell 3000 Index. My data was imported from the yahoo finance library. I am aiming to build a classification framework that can distinguish and predict between the 11 sectors and potentially also generate similar peers.

# %% [markdown]
# The below is a confusion matrix of my preliminary model. This is useful for visualizing where my model is predictively strong (along the diagonal) and where it can be improved (for example, Industrials and Consumer Cyclicals are often misclassified with one another).

# %%
from IPython.display import Image
Image(filename='CF_Matrix.png')

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Ideally my next steps would be to:
# * improve my model further through parameter tuning
# * measure the accuracy of my model not just based on primary classification, but also second choice classification (what the model deemed the second most probably category)
